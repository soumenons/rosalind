# %%
def transcribe_dna(dna):
    rna=""
    for base in dna:
        if base == 'A':
            rna+=base
        elif base == 'C':
            rna+=base
        elif base == 'G':
            rna+=base
        elif base == 'T':
            rna+='U'
        else:
            print("Unknown base in string")
    print(rna)

# %%
transcribe_dna("...")
# Out:
# ...
